# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on: {device}")

# Safely get the number of classes (should be 38)
# We check if 'train_dataset' is a Subset or a full ImageFolder
if hasattr(train_dataset, 'classes'):
    num_classes = len(train_dataset.classes)
else:
    num_classes = len(train_dataset.dataset.classes)

print(f"Number of classes detected: {num_classes}")
# Out:
# Training on: cpu
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8 print(f"Training on: {device}")
#      10 # Safely get the number of classes (should be 38)
#      11 # We check if 'train_dataset' is a Subset or a full ImageFolder
# ---> 12 if hasattr(train_dataset, 'classes'):
#      13     num_classes = len(train_dataset.classes)
#      14 else:
#
# NameError: name 'train_dataset' is not defined
