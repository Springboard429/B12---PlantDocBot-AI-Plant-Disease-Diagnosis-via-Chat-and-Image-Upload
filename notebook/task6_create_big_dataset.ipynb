# %%
import pandas as pd
import random

data = {

    "Pepper__bell___Bacterial_spot": [
        "small dark spots on pepper leaf",
        "bacterial infection on pepper plant",
        "yellow halo around spots",
        "black lesions on pepper foliage",
        "infected bell pepper leaf"
    ],

    "Pepper__bell___healthy": [
        "healthy green pepper leaf",
        "fresh bell pepper foliage",
        "normal pepper plant",
        "disease free pepper leaf",
        "healthy pepper vegetation"
    ],

    "Potato_Early_blight": [
        "brown spots on potato leaf",
        "target shaped lesions",
        "alternaria infection",
        "dry brown potato foliage",
        "potato leaf turning brown"
    ],

    "Potato_healthy": [
        "healthy potato leaf",
        "fresh green potato foliage",
        "disease free potato plant",
        "normal potato vegetation",
        "clean potato leaf"
    ],

    "Potato_Late_blight": [
        "wet black lesions on potato leaf",
        "potato fungal blight",
        "rotting potato foliage",
        "dark patches on potato leaf",
        "infected potato plant"
    ],

    "Tomato_Target_Spot": [
        "target spot lesions on tomato leaf",
        "dark circular tomato spots",
        "fungal target spot disease",
        "brown target lesions",
        "infected tomato target spot"
    ],

    "Tomato_Tomato_mosaic_virus": [
        "mosaic patterns on tomato leaf",
        "viral mosaic disease",
        "distorted tomato foliage",
        "green yellow mosaic symptoms",
        "tomato mosaic infection"
    ],

    "Tomato_Tomato_YellowLeaf_Curl_Virus": [
        "yellow curling tomato leaves",
        "leaf curl virus symptoms",
        "upward curling tomato foliage",
        "yellow twisted leaves",
        "viral tomato curling disease"
    ],

    "Tomato_Bacterial_spot": [
        "small black bacterial spots",
        "bacterial tomato leaf infection",
        "dark lesions with yellow halo",
        "infected tomato foliage",
        "tomato bacterial disease"
    ],

    "Tomato_Early_blight": [
        "target shaped brown spots",
        "alternaria solani infection",
        "brown concentric lesions",
        "dry brown tomato leaf",
        "early blight symptoms"
    ],

    "Tomato_healthy": [
        "healthy tomato leaf",
        "fresh green tomato foliage",
        "normal tomato plant",
        "disease free tomato leaf",
        "healthy tomato vegetation"
    ],

    "Tomato_Late_blight": [
        "dark brown lesions on tomato leaf",
        "water soaked tomato spots",
        "wet fungal tomato disease",
        "rotting tomato foliage",
        "late blight infection"
    ],

    "Tomato_Leaf_Mold": [
        "yellow mold spots under leaf",
        "leaf mold disease",
        "fungal growth beneath tomato leaf",
        "yellow patches on tomato foliage",
        "velvety mold symptoms"
    ],

    "Tomato_Septoria_leaf_spot": [
        "small circular septoria spots",
        "tiny dark tomato lesions",
        "septoria fungal disease",
        "yellow halo around spots",
        "tomato septoria infection"
    ],

    "Tomato_Spider_mites_Two_spotted_spider_mite": [
        "tiny spider mites under leaf",
        "yellow stippling on tomato leaf",
        "webbing under tomato foliage",
        "spider mite infestation",
        "two spotted mites symptoms"
    ]
}

rows = []

for disease, captions in data.items():

    plant = disease.split("_")[0].lower()

    for i in range(1200):

        text = random.choice(captions)

        final_text = f"{plant} leaf {text}"

        rows.append({
            "caption": disease,
            "text": final_text
        })

df = pd.DataFrame(rows)

print(df.head())

print("\nTOTAL ROWS:", len(df))

df.to_parquet("../plantvillage_big.parquet")

print("\n✅ NEW DATASET SAVED")
# Out:
#                          caption  \
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot
#
#                                               text
# 0      pepper leaf small dark spots on pepper leaf
# 1      pepper leaf small dark spots on pepper leaf
# 2      pepper leaf small dark spots on pepper leaf
# 3  pepper leaf bacterial infection on pepper plant
# 4            pepper leaf infected bell pepper leaf
#
# TOTAL ROWS: 18000
#
# ✅ NEW DATASET SAVED
